# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import date
# Import API key
#from api_keys import weather_api_key
from config1 import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
pprint(cities)
len(cities)
# Out:
# ['saint-pierre',
#  'itaituba',
#  'jamestown',
#  'bluff',
#  'punta arenas',
#  'kruisfontein',
#  'mahebourg',
#  'busselton',
#  'yanam',
#  'mataura',
#  'ushuaia',
#  'atuona',
#  'clyde river',
#  'kismayo',
#  'khelyulya',
#  'fort nelson',
#  'belushya guba',
#  'para de minas',
#  'vaini',
#  'pangnirtung',
#  'rikitea',
#  'tessalit',
#  'dikson',
#  'hambantota',
#  'yellowknife',
#  'hobart',
#  'ambilobe',
#  'constitucion',
#  'khatanga',
#  'zhuhai',
#  'souillac',
#  'tuktoyaktuk',
#  'carnarvon',
#  'genhe',
#  'victoria point',
#  'lebu',
#  'taolanaro',
#  'kodiak',
#  'gravdal',
#  'albany',
#  'victoria',
#  'maghama',
#  'bhuban',
#  'santa maria da boa vista',
#  'saleaula',
#  'ouricuri',
#  'esperance',
#  'ahipara',
#  'gat',
#  'ust-nera',
#  'severo-kurilsk',
#  'lancaster',
#  'christchurch',
#  'fortuna',
#  'ayan',
#  'san patricio',
#  'fukue',
#  'saint-philippe',
#  'attawapiskat',
#  'methven',
#  'yerbogachen',
#  'codrington',
#  'banda aceh',
#  'ketchikan',
#  'tromso',
#  'new norfolk',
#  'bredasdorp',
#  'castro',
#  'kirensk',
#  'hermanus',
#  'vardo',
#  'asau',
#  'bambous virieux',
#  'anadyr',
#  'kutum',
#  'thompson',
#  'farmington',
#  'aljustrel',
#  'cidreira',
#  'mogadishu',
#  'hasaki',
#  'arraial do cabo',
#  'puerto ayora',
#  'barentsburg',
#  'nikolskoye',
#  'los llanos de aridane',
#  'chuy',
#  'salalah',
#  'port elizabeth',
#  'ilulissat',
#  'san policarpo',
#  'mnogovershinnyy',
#  'tasiilaq',
#  'kapaa',
#  'tiznit',
#  'yumen',
#  'rawson',
#  'oranjemund',
#  'culipapa',
#  'port alfred',
#  'butaritari',
#  'samusu',
#  'ijaki',
#  'luderitz',
#  'zaykovo',
#  'viligili',
#  'saint george',
#  'rudnichnyy',
#  'hami',
#  'cape town',
#  'cherskiy',
#  'tsihombe',
#  'klaksvik',
#  'celestun',
#  'comodoro rivadavia',
#  'tiksi',
#  'adrar',
#  'kovdor',
#  'porbandar',
#  'ixtapa',
#  'correntina',
#  'guerrero negro',
#  'la ronge',
#  'parrita',
#  'kargasok',
#  'amderma',
#  'rodeo',
#  'calvinia',
#  'kahului',
#  'coquimbo',
#  'chokurdakh',
#  'vaitupu',
#  'mys shmidta',
#  'narasannapeta',
#  'selcuk',
#  'merauke',
#  'mamontovo',
#  'kamenskoye',
#  'shaoguan',
#  'bar harbor',
#  'lloydminster',
#  'fushun',
#  'hilo',
#  'zemio',
#  'rio cuarto',
#  'talnakh',
#  'yar-sale',
#  'mar del plata',
#  'tokur',
#  'seoul',
#  'ostrovnoy',
#  'kamenka',
#  'satitoa',
#  'la foa',
#  'georgetown',
#  'bugama',
#  'soyo',
#  'mae hong son',
#  'sakakah',
#  'robertsport',
#  'okha',
#  'bethel',
#  'lumphat',
#  'illoqqortoormiut',
#  'cap-aux-meules',
#  'hastings',
#  'leningradskiy',
#  'qaanaaq',
#  'sao joao da barra',
#  'batsfjord',
#  'avarua',
#  'aflu',
#  'kiunga',
#  'simpang empat',
#  'zhanakorgan',
#  'coihaique',
#  'grand gaube',
#  'marsh harbour',
#  'pisco',
#  'garwolin',
#  'mitsamiouli',
#  'avon lake',
#  'pingxiang',
#  'quatre cocos',
#  'ribeira grande',
#  'hithadhoo',
#  'walvis bay',
#  'aksarka',
#  'tarauaca',
#  'alofi',
#  'sestroretsk',
#  'sola',
#  'sentyabrskiy',
#  'high level',
#  'port hardy',
#  'naantali',
#  'hamilton',
#  'bengkulu',
#  'namatanai',
#  'tual',
#  'vila velha',
#  'tolu',
#  'karmana',
#  'aldan',
#  'saint andrews',
#  'tartagal',
#  'narsaq',
#  'hokitika',
#  'upernavik',
#  'rocha',
#  'kungurtug',
#  'daru',
#  'padang',
#  'san angelo',
#  'provideniya',
#  'bilma',
#  'komsomolskiy',
#  'santa cruz',
#  'kui buri',
#  'frederico westphalen',
#  'oakdale',
#  'taltal',
#  'grand river south east',
#  'ascension',
#  'umzimvubu',
#  'howard springs',
#  'nanortalik',
#  'andalan',
#  'dingle',
#  'kaeo',
#  'north platte',
#  'jumla',
#  'wembley',
#  'san francisco del mar',
#  'akhtubinsk',
#  'xai-xai',
#  'san carlos de bariloche',
#  'beyneu',
#  'belmonte',
#  'fairbanks',
#  'khatra',
#  'marsa matruh',
#  'berlevag',
#  'pasni',
#  'barrow',
#  'mayo',
#  'mardin',
#  'ponta do sol',
#  'itarema',
#  'towada',
#  'kabanjahe',
#  'kaitangata',
#  'taoudenni',
#  'east london',
#  'the pas',
#  'vila franca do campo',
#  'airai',
#  'santa rosa',
#  'la rioja',
#  'sokoni',
#  'cayenne',
#  'idaho falls',
#  'palabuhanratu',
#  'mandera',
#  'port lincoln',
#  'el alto',
#  'katsuura',
#  'san nicolas',
#  'nizhneyansk',
#  'is',
#  'sechura',
#  'chapais',
#  'coahuayana',
#  'shumskiy',
#  'moron',
#  'shiraz',
#  'stromness',
#  'ugoofaaru',
#  'port blair',
#  'sao filipe',
#  'puerto escondido',
#  'naze',
#  'bonoua',
#  'porto novo',
#  'kurilsk',
#  'boende',
#  'general roca',
#  'perth',
#  'cochrane',
#  'oriximina',
#  'la victoria',
#  'sereflikochisar',
#  'lima',
#  'coos bay',
#  'mrirt',
#  'shingu',
#  'panaba',
#  'manaus',
#  'lorengau',
#  'lavrentiya',
#  'zhezkazgan',
#  'houma',
#  'gladstone',
#  'launceston',
#  'sabzevar',
#  'karratha',
#  'lata',
#  'sfantu gheorghe',
#  'wakkanai',
#  'jaciara',
#  'lompoc',
#  'belaya gora',
#  'port pirie',
#  'cabo san lucas',
#  'skagastrond',
#  'boa vista',
#  'paamiut',
#  'takoradi',
#  'zheleznodorozhnyy',
#  'faya',
#  'hervey bay',
#  'owosso',
#  'kichera',
#  'sambava',
#  'kasongo-lunda',
#  'marzuq',
#  'paradwip',
#  'mercedes',
#  'saldanha',
#  'jinchang',
#  'nouakchott',
#  'krasnoselkup',
#  'zhigansk',
#  'pevek',
#  'teluk nibung',
#  'isangel',
#  'trincomalee',
#  'elat',
#  'pacasmayo',
#  'bardsir',
#  'batticaloa',
#  'one hundred mile house',
#  'estepa',
#  'kavieng',
#  'perelyub',
#  'rio gallegos',
#  'ludvika',
#  'lasa',
#  'kalakamati',
#  'yanchukan',
#  'sol-iletsk',
#  'iralaya',
#  'zachagansk',
#  'altamira',
#  'stornoway',
#  'waipawa',
#  'at-bashi',
#  'sao geraldo do araguaia',
#  'kysucke nove mesto',
#  'lisakovsk',
#  'port macquarie',
#  'yeghegnavan',
#  'yilan',
#  'ciras',
#  'faanui',
#  'marienburg',
#  'shujaabad',
#  'san ramon',
#  'mariental',
#  'kelebia',
#  'palmer',
#  'alice springs',
#  'norman wells',
#  'fandriana',
#  'san juan del parana',
#  'sorland',
#  'almaznyy',
#  'alugan',
#  'kindu',
#  'curuca',
#  'flinders',
#  'beringovskiy',
#  'oktyabrskoye',
#  'santa lucia',
#  'marcona',
#  'kushima',
#  'betare oya',
#  'burica',
#  'vostok',
#  'tsentralnyy',
#  'obidos',
#  'ancud',
#  'avera',
#  'fuling',
#  'noyabrsk',
#  'honningsvag',
#  'haapu',
#  'mount gambier',
#  'setermoen',
#  'longyearbyen',
#  'huambo',
#  'plettenberg bay',
#  'mindelo',
#  'golden',
#  'kozhevnikovo',
#  'meadville',
#  'poso',
#  'syracuse',
#  'oussouye',
#  'northam',
#  'carauari',
#  'klyuchi',
#  'dakar',
#  'bhinmal',
#  'portland',
#  'laguna',
#  'margate',
#  'cairns',
#  'thinadhoo',
#  'nurota',
#  'panzhihua',
#  'kaitong',
#  'rio verde de mato grosso',
#  'sorvag',
#  'torbay',
#  'salinopolis',
#  'ballitoville',
#  'saint-augustin',
#  'tabiauea',
#  'uray',
#  'moose factory',
#  'caravelas',
#  'kenai',
#  'shache',
#  'egvekinot',
#  'ati',
#  'san jose',
#  'leeton',
#  'ibra',
#  'cap malheureux',
#  'henties bay',
#  'ginir',
#  'lagoa',
#  'dunedin',
#  'srednekolymsk',
#  'talara',
#  'imeni poliny osipenko',
#  'menongue',
#  'savyntsi',
#  'araci',
#  'hrebinka',
#  'broome',
#  'olafsvik',
#  'chimbote',
#  'catia la mar',
#  'kingaroy',
#  'callaway',
#  'kerman',
#  'valparaiso',
#  'saskylakh',
#  'dwarka',
#  'chumphon',
#  'kade',
#  'sapulpa',
#  'babu',
#  'biak',
#  'geraldton',
#  'la orilla',
#  'agbor',
#  'huarmey',
#  'caucaia',
#  'maumere',
#  'richards bay',
#  'rio de jesus',
#  'veraval',
#  'namibe',
#  'peruibe',
#  'seydi',
#  'merate',
#  'atar',
#  'port moresby',
#  'pauini',
#  'kodinsk',
#  'pitimbu',
#  'katherine',
#  'killybegs',
#  'brae',
#  'boffa',
#  'socorro',
#  'yangambi',
#  'tautira',
#  'debre tabor',
#  'khani',
#  'asyut',
#  'coronado',
#  'nhulunbuy',
#  'lakeside',
#  'liverpool',
#  'tocopilla',
#  'piura',
#  'havoysund',
#  'buala',
#  'kolpashevo',
#  'linqiong',
#  'inderborskiy',
#  'tumannyy',
#  'tanshui',
#  'mananara',
#  'nouadhibou',
#  'bubaque',
#  'wanlaweyn',
#  'praxedis guerrero',
#  'khonuu',
#  'safaqis',
#  'touros',
#  'kiama',
#  'evensk',
#  'port-cartier',
#  'bogale',
#  'sioux lookout',
#  'hailar',
#  'kangasala',
#  'san lorenzo',
#  'vilhena',
#  'halalo',
#  'tumpat',
#  'monrovia',
#  'tommot',
#  'cabatuan',
#  'biankouma',
#  'vredendal',
#  'san cristobal',
#  'santa maria',
#  'pacific grove',
#  'wajir',
#  'lexington park',
#  'batemans bay',
#  'pokhara',
#  'bumba',
#  'acapulco',
#  'gualaquiza',
#  'san quintin',
#  'paungde',
#  'barcelos',
#  'te anau',
#  'zhireken',
#  'camacha',
#  'wolmaranstad',
#  'hohhot',
#  'haibowan',
#  'kjollefjord',
#  'kupang',
#  'medford',
#  'lolua',
#  'bangui',
#  'marawi',
#  'westport',
#  'mandalgovi',
#  'kawalu',
#  'gizo',
#  'puerto vallarta',
#  'rosetta',
#  'camacupa',
#  'kavaratti',
#  'abengourou',
#  'norrtalje',
#  'kodino',
#  'iqaluit',
#  'tandil',
#  'kuvandyk',
#  'kargala',
#  'sayabec',
#  'prince rupert',
#  'morecambe',
#  'rudbar',
#  'khorixas',
#  'temaraia',
#  'taywarah',
#  'keti bandar',
#  'ciudad del maiz',
#  'ous',
#  'manokwari',
#  'nago',
#  'aykhal',
#  'wanaka',
#  'harper',
#  'sibolga',
#  'shimoda',
#  'kieta',
#  'tura',
#  'manitouwadge',
#  'rutul',
#  'yatou']
# 593

# %%
# Save config information.
url =  "http://api.openweathermap.org/data/2.5/weather?"

# Build partial query URL
units="metric"
query_url = f"{url}appid={weather_api_key}&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
 #city_re=requests.get(query_url + city+ "&units=" + units).json()

# %%
humidity=[]
counter = 0
print(f'Beginning Data Retrieval')  
print(f'-----------------------------')
for city in cities:
    counter = counter + 1
  
    response=requests.get(query_url + city+ "&units=" + units).json()
   
    try: 
   
        print(f'Processing Record {counter} of set 1 |{city}' ) 
    except:
            print(f'City not found. Skipping...:{city}')
            pass
print(f'-----------------------------')   
print(f'Ending of Data Retrieval')  
print(f'-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1 |saint-pierre
# Processing Record 2 of set 1 |itaituba
# Processing Record 3 of set 1 |jamestown
# Processing Record 4 of set 1 |bluff
# Processing Record 5 of set 1 |punta arenas
# Processing Record 6 of set 1 |kruisfontein
# Processing Record 7 of set 1 |mahebourg
# Processing Record 8 of set 1 |busselton
# Processing Record 9 of set 1 |yanam
# Processing Record 10 of set 1 |mataura
# Processing Record 11 of set 1 |ushuaia
# Processing Record 12 of set 1 |atuona
# Processing Record 13 of set 1 |clyde river
# Processing Record 14 of set 1 |kismayo
# Processing Record 15 of set 1 |khelyulya
# Processing Record 16 of set 1 |fort nelson
# Processing Record 17 of set 1 |belushya guba
# Processing Record 18 of set 1 |para de minas
# Processing Record 19 of set 1 |vaini
# Processing Record 20 of set 1 |pangnirtung
# Processing Record 21 of set 1 |rikitea
# Processing Record 22 of set 1 |tessalit
# Processing Record 23 of set 1 |dikson
# Processing Record 24 of set 1 |hambantota
# Processing Record 25 of set 1 |yellowknife
# Processing Record 26 of set 1 |hobart
# Processing Record 27 of set 1 |ambilobe
# Processing Record 28 of set 1 |constitucion
# Processing Record 29 of set 1 |khatanga
# Processing Record 30 of set 1 |zhuhai
# Processing Record 31 of set 1 |souillac
# Processing Record 32 of set 1 |tuktoyaktuk
# Processing Record 33 of set 1 |carnarvon
# Processing Record 34 of set 1 |genhe
# Processing Record 35 of set 1 |victoria point
# Processing Record 36 of set 1 |lebu
# Processing Record 37 of set 1 |taolanaro
# Processing Record 38 of set 1 |kodiak
# Processing Record 39 of set 1 |gravdal
# Processing Record 40 of set 1 |albany
# Processing Record 41 of set 1 |victoria
# Processing Record 42 of set 1 |maghama
# Processing Record 43 of set 1 |bhuban
# Processing Record 44 of set 1 |santa maria da boa vista
# Processing Record 45 of set 1 |saleaula
# Processing Record 46 of set 1 |ouricuri
# Processing Record 47 of set 1 |esperance
# Processing Record 48 of set 1 |ahipara
# Processing Record 49 of set 1 |gat
# Processing Record 50 of set 1 |ust-nera
# Processing Record 51 of set 1 |severo-kurilsk
# Processing Record 52 of set 1 |lancaster
# Processing Record 53 of set 1 |christchurch
# Processing Record 54 of set 1 |fortuna
# Processing Record 55 of set 1 |ayan
# Processing Record 56 of set 1 |san patricio
# Processing Record 57 of set 1 |fukue
# Processing Record 58 of set 1 |saint-philippe
# Processing Record 59 of set 1 |attawapiskat
# Processing Record 60 of set 1 |methven
# Processing Record 61 of set 1 |yerbogachen
# Processing Record 62 of set 1 |codrington
# Processing Record 63 of set 1 |banda aceh
# Processing Record 64 of set 1 |ketchikan
# Processing Record 65 of set 1 |tromso
# Processing Record 66 of set 1 |new norfolk
# Processing Record 67 of set 1 |bredasdorp
# Processing Record 68 of set 1 |castro
# Processing Record 69 of set 1 |kirensk
# Processing Record 70 of set 1 |hermanus
# Processing Record 71 of set 1 |vardo
# Processing Record 72 of set 1 |asau
# Processing Record 73 of set 1 |bambous virieux
# Processing Record 74 of set 1 |anadyr
# Processing Record 75 of set 1 |kutum
# Processing Record 76 of set 1 |thompson
# Processing Record 77 of set 1 |farmington
# Processing Record 78 of set 1 |aljustrel
# Processing Record 79 of set 1 |cidreira
# Processing Record 80 of set 1 |mogadishu
# Processing Record 81 of set 1 |hasaki
# Processing Record 82 of set 1 |arraial do cabo
# Processing Record 83 of set 1 |puerto ayora
# Processing Record 84 of set 1 |barentsburg
# Processing Record 85 of set 1 |nikolskoye
# Processing Record 86 of set 1 |los llanos de aridane
# Processing Record 87 of set 1 |chuy
# Processing Record 88 of set 1 |salalah
# Processing Record 89 of set 1 |port elizabeth
# Processing Record 90 of set 1 |ilulissat
# Processing Record 91 of set 1 |san policarpo
# Processing Record 92 of set 1 |mnogovershinnyy
# Processing Record 93 of set 1 |tasiilaq
# Processing Record 94 of set 1 |kapaa
# Processing Record 95 of set 1 |tiznit
# Processing Record 96 of set 1 |yumen
# Processing Record 97 of set 1 |rawson
# Processing Record 98 of set 1 |oranjemund
# Processing Record 99 of set 1 |culipapa
# Processing Record 100 of set 1 |port alfred
# Processing Record 101 of set 1 |butaritari
# Processing Record 102 of set 1 |samusu
# Processing Record 103 of set 1 |ijaki
# Processing Record 104 of set 1 |luderitz
# Processing Record 105 of set 1 |zaykovo
# Processing Record 106 of set 1 |viligili
# Processing Record 107 of set 1 |saint george
# Processing Record 108 of set 1 |rudnichnyy
# Processing Record 109 of set 1 |hami
# Processing Record 110 of set 1 |cape town
# Processing Record 111 of set 1 |cherskiy
# Processing Record 112 of set 1 |tsihombe
# Processing Record 113 of set 1 |klaksvik
# Processing Record 114 of set 1 |celestun
# Processing Record 115 of set 1 |comodoro rivadavia
# Processing Record 116 of set 1 |tiksi
# Processing Record 117 of set 1 |adrar
# Processing Record 118 of set 1 |kovdor
# Processing Record 119 of set 1 |porbandar
# Processing Record 120 of set 1 |ixtapa
# Processing Record 121 of set 1 |correntina
# Processing Record 122 of set 1 |guerrero negro
# Processing Record 123 of set 1 |la ronge
# Processing Record 124 of set 1 |parrita
# Processing Record 125 of set 1 |kargasok
# Processing Record 126 of set 1 |amderma
# Processing Record 127 of set 1 |rodeo
# Processing Record 128 of set 1 |calvinia
# Processing Record 129 of set 1 |kahului
# Processing Record 130 of set 1 |coquimbo
# Processing Record 131 of set 1 |chokurdakh
# Processing Record 132 of set 1 |vaitupu
# Processing Record 133 of set 1 |mys shmidta
# Processing Record 134 of set 1 |narasannapeta
# Processing Record 135 of set 1 |selcuk
# Processing Record 136 of set 1 |merauke
# Processing Record 137 of set 1 |mamontovo
# Processing Record 138 of set 1 |kamenskoye
# Processing Record 139 of set 1 |shaoguan
# Processing Record 140 of set 1 |bar harbor
# Processing Record 141 of set 1 |lloydminster
# Processing Record 142 of set 1 |fushun
# Processing Record 143 of set 1 |hilo
# Processing Record 144 of set 1 |zemio
# Processing Record 145 of set 1 |rio cuarto
# Processing Record 146 of set 1 |talnakh
# Processing Record 147 of set 1 |yar-sale
# Processing Record 148 of set 1 |mar del plata
# Processing Record 149 of set 1 |tokur
# Processing Record 150 of set 1 |seoul
# Processing Record 151 of set 1 |ostrovnoy
# Processing Record 152 of set 1 |kamenka
# Processing Record 153 of set 1 |satitoa
# Processing Record 154 of set 1 |la foa
# Processing Record 155 of set 1 |georgetown
# Processing Record 156 of set 1 |bugama
# Processing Record 157 of set 1 |soyo
# Processing Record 158 of set 1 |mae hong son
# Processing Record 159 of set 1 |sakakah
# Processing Record 160 of set 1 |robertsport
# Processing Record 161 of set 1 |okha
# Processing Record 162 of set 1 |bethel
# Processing Record 163 of set 1 |lumphat
# Processing Record 164 of set 1 |illoqqortoormiut
# Processing Record 165 of set 1 |cap-aux-meules
# Processing Record 166 of set 1 |hastings
# Processing Record 167 of set 1 |leningradskiy
# Processing Record 168 of set 1 |qaanaaq
# Processing Record 169 of set 1 |sao joao da barra
# Processing Record 170 of set 1 |batsfjord
# Processing Record 171 of set 1 |avarua
# Processing Record 172 of set 1 |aflu
# Processing Record 173 of set 1 |kiunga
# Processing Record 174 of set 1 |simpang empat
# Processing Record 175 of set 1 |zhanakorgan
# Processing Record 176 of set 1 |coihaique
# Processing Record 177 of set 1 |grand gaube
# Processing Record 178 of set 1 |marsh harbour
# Processing Record 179 of set 1 |pisco
# Processing Record 180 of set 1 |garwolin
# Processing Record 181 of set 1 |mitsamiouli
# Processing Record 182 of set 1 |avon lake
# Processing Record 183 of set 1 |pingxiang
# Processing Record 184 of set 1 |quatre cocos
# Processing Record 185 of set 1 |ribeira grande
# Processing Record 186 of set 1 |hithadhoo
# Processing Record 187 of set 1 |walvis bay
# Processing Record 188 of set 1 |aksarka
# Processing Record 189 of set 1 |tarauaca
# Processing Record 190 of set 1 |alofi
# Processing Record 191 of set 1 |sestroretsk
# Processing Record 192 of set 1 |sola
# Processing Record 193 of set 1 |sentyabrskiy
# Processing Record 194 of set 1 |high level
# Processing Record 195 of set 1 |port hardy
# Processing Record 196 of set 1 |naantali
# Processing Record 197 of set 1 |hamilton
# Processing Record 198 of set 1 |bengkulu
# Processing Record 199 of set 1 |namatanai
# Processing Record 200 of set 1 |tual
# Processing Record 201 of set 1 |vila velha
# Processing Record 202 of set 1 |tolu
# Processing Record 203 of set 1 |karmana
# Processing Record 204 of set 1 |aldan
# Processing Record 205 of set 1 |saint andrews
# Processing Record 206 of set 1 |tartagal
# Processing Record 207 of set 1 |narsaq
# Processing Record 208 of set 1 |hokitika
# Processing Record 209 of set 1 |upernavik
# Processing Record 210 of set 1 |rocha
# Processing Record 211 of set 1 |kungurtug
# Processing Record 212 of set 1 |daru
# Processing Record 213 of set 1 |padang
# Processing Record 214 of set 1 |san angelo
# Processing Record 215 of set 1 |provideniya
# Processing Record 216 of set 1 |bilma
# Processing Record 217 of set 1 |komsomolskiy
# Processing Record 218 of set 1 |santa cruz
# Processing Record 219 of set 1 |kui buri
# Processing Record 220 of set 1 |frederico westphalen
# Processing Record 221 of set 1 |oakdale
# Processing Record 222 of set 1 |taltal
# Processing Record 223 of set 1 |grand river south east
# Processing Record 224 of set 1 |ascension
# Processing Record 225 of set 1 |umzimvubu
# Processing Record 226 of set 1 |howard springs
# Processing Record 227 of set 1 |nanortalik
# Processing Record 228 of set 1 |andalan
# Processing Record 229 of set 1 |dingle
# Processing Record 230 of set 1 |kaeo
# Processing Record 231 of set 1 |north platte
# Processing Record 232 of set 1 |jumla
# Processing Record 233 of set 1 |wembley
# Processing Record 234 of set 1 |san francisco del mar
# Processing Record 235 of set 1 |akhtubinsk
# Processing Record 236 of set 1 |xai-xai
# Processing Record 237 of set 1 |san carlos de bariloche
# Processing Record 238 of set 1 |beyneu
# Processing Record 239 of set 1 |belmonte
# Processing Record 240 of set 1 |fairbanks
# Processing Record 241 of set 1 |khatra
# Processing Record 242 of set 1 |marsa matruh
# Processing Record 243 of set 1 |berlevag
# Processing Record 244 of set 1 |pasni
# Processing Record 245 of set 1 |barrow
# Processing Record 246 of set 1 |mayo
# Processing Record 247 of set 1 |mardin
# Processing Record 248 of set 1 |ponta do sol
# Processing Record 249 of set 1 |itarema
# Processing Record 250 of set 1 |towada
# Processing Record 251 of set 1 |kabanjahe
# Processing Record 252 of set 1 |kaitangata
# Processing Record 253 of set 1 |taoudenni
# Processing Record 254 of set 1 |east london
# Processing Record 255 of set 1 |the pas
# Processing Record 256 of set 1 |vila franca do campo
# Processing Record 257 of set 1 |airai
# Processing Record 258 of set 1 |santa rosa
# Processing Record 259 of set 1 |la rioja
# Processing Record 260 of set 1 |sokoni
# Processing Record 261 of set 1 |cayenne
# Processing Record 262 of set 1 |idaho falls
# Processing Record 263 of set 1 |palabuhanratu
# Processing Record 264 of set 1 |mandera
# Processing Record 265 of set 1 |port lincoln
# Processing Record 266 of set 1 |el alto
# Processing Record 267 of set 1 |katsuura
# Processing Record 268 of set 1 |san nicolas
# Processing Record 269 of set 1 |nizhneyansk
# Processing Record 270 of set 1 |is
# Processing Record 271 of set 1 |sechura
# Processing Record 272 of set 1 |chapais
# Processing Record 273 of set 1 |coahuayana
# Processing Record 274 of set 1 |shumskiy
# Processing Record 275 of set 1 |moron
# Processing Record 276 of set 1 |shiraz
# Processing Record 277 of set 1 |stromness
# Processing Record 278 of set 1 |ugoofaaru
# Processing Record 279 of set 1 |port blair
# Processing Record 280 of set 1 |sao filipe
# Processing Record 281 of set 1 |puerto escondido
# Processing Record 282 of set 1 |naze
# Processing Record 283 of set 1 |bonoua
# Processing Record 284 of set 1 |porto novo
# Processing Record 285 of set 1 |kurilsk
# Processing Record 286 of set 1 |boende
# Processing Record 287 of set 1 |general roca
# Processing Record 288 of set 1 |perth
# Processing Record 289 of set 1 |cochrane
# Processing Record 290 of set 1 |oriximina
# Processing Record 291 of set 1 |la victoria
# Processing Record 292 of set 1 |sereflikochisar
# Processing Record 293 of set 1 |lima
# Processing Record 294 of set 1 |coos bay
# Processing Record 295 of set 1 |mrirt
# Processing Record 296 of set 1 |shingu
# Processing Record 297 of set 1 |panaba
# Processing Record 298 of set 1 |manaus
# Processing Record 299 of set 1 |lorengau
# Processing Record 300 of set 1 |lavrentiya
# Processing Record 301 of set 1 |zhezkazgan
# Processing Record 302 of set 1 |houma
# Processing Record 303 of set 1 |gladstone
# Processing Record 304 of set 1 |launceston
# Processing Record 305 of set 1 |sabzevar
# Processing Record 306 of set 1 |karratha
# Processing Record 307 of set 1 |lata
# Processing Record 308 of set 1 |sfantu gheorghe
# Processing Record 309 of set 1 |wakkanai
# Processing Record 310 of set 1 |jaciara
# Processing Record 311 of set 1 |lompoc
# Processing Record 312 of set 1 |belaya gora
# Processing Record 313 of set 1 |port pirie
# Processing Record 314 of set 1 |cabo san lucas
# Processing Record 315 of set 1 |skagastrond
# Processing Record 316 of set 1 |boa vista
# Processing Record 317 of set 1 |paamiut
# Processing Record 318 of set 1 |takoradi
# Processing Record 319 of set 1 |zheleznodorozhnyy
# Processing Record 320 of set 1 |faya
# Processing Record 321 of set 1 |hervey bay
# Processing Record 322 of set 1 |owosso
# Processing Record 323 of set 1 |kichera
# Processing Record 324 of set 1 |sambava
# Processing Record 325 of set 1 |kasongo-lunda
# Processing Record 326 of set 1 |marzuq
# Processing Record 327 of set 1 |paradwip
# Processing Record 328 of set 1 |mercedes
# Processing Record 329 of set 1 |saldanha
# Processing Record 330 of set 1 |jinchang
# Processing Record 331 of set 1 |nouakchott
# Processing Record 332 of set 1 |krasnoselkup
# Processing Record 333 of set 1 |zhigansk
# Processing Record 334 of set 1 |pevek
# Processing Record 335 of set 1 |teluk nibung
# Processing Record 336 of set 1 |isangel
# Processing Record 337 of set 1 |trincomalee
# Processing Record 338 of set 1 |elat
# Processing Record 339 of set 1 |pacasmayo
# Processing Record 340 of set 1 |bardsir
# Processing Record 341 of set 1 |batticaloa
# Processing Record 342 of set 1 |one hundred mile house
# Processing Record 343 of set 1 |estepa
# Processing Record 344 of set 1 |kavieng
# Processing Record 345 of set 1 |perelyub
# Processing Record 346 of set 1 |rio gallegos
# Processing Record 347 of set 1 |ludvika
# Processing Record 348 of set 1 |lasa
# Processing Record 349 of set 1 |kalakamati
# Processing Record 350 of set 1 |yanchukan
# Processing Record 351 of set 1 |sol-iletsk
# Processing Record 352 of set 1 |iralaya
# Processing Record 353 of set 1 |zachagansk
# Processing Record 354 of set 1 |altamira
# Processing Record 355 of set 1 |stornoway
# Processing Record 356 of set 1 |waipawa
# Processing Record 357 of set 1 |at-bashi
# Processing Record 358 of set 1 |sao geraldo do araguaia
# Processing Record 359 of set 1 |kysucke nove mesto
# Processing Record 360 of set 1 |lisakovsk
# Processing Record 361 of set 1 |port macquarie
# Processing Record 362 of set 1 |yeghegnavan
# Processing Record 363 of set 1 |yilan
# Processing Record 364 of set 1 |ciras
# Processing Record 365 of set 1 |faanui
# Processing Record 366 of set 1 |marienburg
# Processing Record 367 of set 1 |shujaabad
# Processing Record 368 of set 1 |san ramon
# Processing Record 369 of set 1 |mariental
# Processing Record 370 of set 1 |kelebia
# Processing Record 371 of set 1 |palmer
# Processing Record 372 of set 1 |alice springs
# Processing Record 373 of set 1 |norman wells
# Processing Record 374 of set 1 |fandriana
# Processing Record 375 of set 1 |san juan del parana
# Processing Record 376 of set 1 |sorland
# Processing Record 377 of set 1 |almaznyy
# Processing Record 378 of set 1 |alugan
# Processing Record 379 of set 1 |kindu
# Processing Record 380 of set 1 |curuca
# Processing Record 381 of set 1 |flinders
# Processing Record 382 of set 1 |beringovskiy
# Processing Record 383 of set 1 |oktyabrskoye
# Processing Record 384 of set 1 |santa lucia
# Processing Record 385 of set 1 |marcona
# Processing Record 386 of set 1 |kushima
# Processing Record 387 of set 1 |betare oya
# Processing Record 388 of set 1 |burica
# Processing Record 389 of set 1 |vostok
# Processing Record 390 of set 1 |tsentralnyy
# Processing Record 391 of set 1 |obidos
# Processing Record 392 of set 1 |ancud
# Processing Record 393 of set 1 |avera
# Processing Record 394 of set 1 |fuling
# Processing Record 395 of set 1 |noyabrsk
# Processing Record 396 of set 1 |honningsvag
# Processing Record 397 of set 1 |haapu
# Processing Record 398 of set 1 |mount gambier
# Processing Record 399 of set 1 |setermoen
# Processing Record 400 of set 1 |longyearbyen
# Processing Record 401 of set 1 |huambo
# Processing Record 402 of set 1 |plettenberg bay
# Processing Record 403 of set 1 |mindelo
# Processing Record 404 of set 1 |golden
# Processing Record 405 of set 1 |kozhevnikovo
# Processing Record 406 of set 1 |meadville
# Processing Record 407 of set 1 |poso
# Processing Record 408 of set 1 |syracuse
# Processing Record 409 of set 1 |oussouye
# Processing Record 410 of set 1 |northam
# Processing Record 411 of set 1 |carauari
# Processing Record 412 of set 1 |klyuchi
# Processing Record 413 of set 1 |dakar
# Processing Record 414 of set 1 |bhinmal
# Processing Record 415 of set 1 |portland
# Processing Record 416 of set 1 |laguna
# Processing Record 417 of set 1 |margate
# Processing Record 418 of set 1 |cairns
# Processing Record 419 of set 1 |thinadhoo
# Processing Record 420 of set 1 |nurota
# Processing Record 421 of set 1 |panzhihua
# Processing Record 422 of set 1 |kaitong
# Processing Record 423 of set 1 |rio verde de mato grosso
# Processing Record 424 of set 1 |sorvag
# Processing Record 425 of set 1 |torbay
# Processing Record 426 of set 1 |salinopolis
# Processing Record 427 of set 1 |ballitoville
# Processing Record 428 of set 1 |saint-augustin
# Processing Record 429 of set 1 |tabiauea
# Processing Record 430 of set 1 |uray
# Processing Record 431 of set 1 |moose factory
# Processing Record 432 of set 1 |caravelas
# Processing Record 433 of set 1 |kenai
# Processing Record 434 of set 1 |shache
# Processing Record 435 of set 1 |egvekinot
# Processing Record 436 of set 1 |ati
# Processing Record 437 of set 1 |san jose
# Processing Record 438 of set 1 |leeton
# Processing Record 439 of set 1 |ibra
# Processing Record 440 of set 1 |cap malheureux
# Processing Record 441 of set 1 |henties bay
# Processing Record 442 of set 1 |ginir
# Processing Record 443 of set 1 |lagoa
# Processing Record 444 of set 1 |dunedin
# Processing Record 445 of set 1 |srednekolymsk
# Processing Record 446 of set 1 |talara
# Processing Record 447 of set 1 |imeni poliny osipenko
# Processing Record 448 of set 1 |menongue
# Processing Record 449 of set 1 |savyntsi
# Processing Record 450 of set 1 |araci
# Processing Record 451 of set 1 |hrebinka
# Processing Record 452 of set 1 |broome
# Processing Record 453 of set 1 |olafsvik
# Processing Record 454 of set 1 |chimbote
# Processing Record 455 of set 1 |catia la mar
# Processing Record 456 of set 1 |kingaroy
# Processing Record 457 of set 1 |callaway
# Processing Record 458 of set 1 |kerman
# Processing Record 459 of set 1 |valparaiso
# Processing Record 460 of set 1 |saskylakh
# Processing Record 461 of set 1 |dwarka
# Processing Record 462 of set 1 |chumphon
# Processing Record 463 of set 1 |kade
# Processing Record 464 of set 1 |sapulpa
# Processing Record 465 of set 1 |babu
# Processing Record 466 of set 1 |biak
# Processing Record 467 of set 1 |geraldton
# Processing Record 468 of set 1 |la orilla
# Processing Record 469 of set 1 |agbor
# Processing Record 470 of set 1 |huarmey
# Processing Record 471 of set 1 |caucaia
# Processing Record 472 of set 1 |maumere
# Processing Record 473 of set 1 |richards bay
# Processing Record 474 of set 1 |rio de jesus
# Processing Record 475 of set 1 |veraval
# Processing Record 476 of set 1 |namibe
# Processing Record 477 of set 1 |peruibe
# Processing Record 478 of set 1 |seydi
# Processing Record 479 of set 1 |merate
# Processing Record 480 of set 1 |atar
# Processing Record 481 of set 1 |port moresby
# Processing Record 482 of set 1 |pauini
# Processing Record 483 of set 1 |kodinsk
# Processing Record 484 of set 1 |pitimbu
# Processing Record 485 of set 1 |katherine
# Processing Record 486 of set 1 |killybegs
# Processing Record 487 of set 1 |brae
# Processing Record 488 of set 1 |boffa
# Processing Record 489 of set 1 |socorro
# Processing Record 490 of set 1 |yangambi
# Processing Record 491 of set 1 |tautira
# Processing Record 492 of set 1 |debre tabor
# Processing Record 493 of set 1 |khani
# Processing Record 494 of set 1 |asyut
# Processing Record 495 of set 1 |coronado
# Processing Record 496 of set 1 |nhulunbuy
# Processing Record 497 of set 1 |lakeside
# Processing Record 498 of set 1 |liverpool
# Processing Record 499 of set 1 |tocopilla
# Processing Record 500 of set 1 |piura
# Processing Record 501 of set 1 |havoysund
# Processing Record 502 of set 1 |buala
# Processing Record 503 of set 1 |kolpashevo
# Processing Record 504 of set 1 |linqiong
# Processing Record 505 of set 1 |inderborskiy
# Processing Record 506 of set 1 |tumannyy
# Processing Record 507 of set 1 |tanshui
# Processing Record 508 of set 1 |mananara
# Processing Record 509 of set 1 |nouadhibou
# Processing Record 510 of set 1 |bubaque
# Processing Record 511 of set 1 |wanlaweyn
# Processing Record 512 of set 1 |praxedis guerrero
# Processing Record 513 of set 1 |khonuu
# Processing Record 514 of set 1 |safaqis
# Processing Record 515 of set 1 |touros
# Processing Record 516 of set 1 |kiama
# Processing Record 517 of set 1 |evensk
# Processing Record 518 of set 1 |port-cartier
# Processing Record 519 of set 1 |bogale
# Processing Record 520 of set 1 |sioux lookout
# Processing Record 521 of set 1 |hailar
# Processing Record 522 of set 1 |kangasala
# Processing Record 523 of set 1 |san lorenzo
# Processing Record 524 of set 1 |vilhena
# Processing Record 525 of set 1 |halalo
# Processing Record 526 of set 1 |tumpat
# Processing Record 527 of set 1 |monrovia
# Processing Record 528 of set 1 |tommot
# Processing Record 529 of set 1 |cabatuan
# Processing Record 530 of set 1 |biankouma
# Processing Record 531 of set 1 |vredendal
# Processing Record 532 of set 1 |san cristobal
# Processing Record 533 of set 1 |santa maria
# Processing Record 534 of set 1 |pacific grove
# Processing Record 535 of set 1 |wajir
# Processing Record 536 of set 1 |lexington park
# Processing Record 537 of set 1 |batemans bay
# Processing Record 538 of set 1 |pokhara
# Processing Record 539 of set 1 |bumba
# Processing Record 540 of set 1 |acapulco
# Processing Record 541 of set 1 |gualaquiza
# Processing Record 542 of set 1 |san quintin
# Processing Record 543 of set 1 |paungde
# Processing Record 544 of set 1 |barcelos
# Processing Record 545 of set 1 |te anau
# Processing Record 546 of set 1 |zhireken
# Processing Record 547 of set 1 |camacha
# Processing Record 548 of set 1 |wolmaranstad
# Processing Record 549 of set 1 |hohhot
# Processing Record 550 of set 1 |haibowan
# Processing Record 551 of set 1 |kjollefjord
# Processing Record 552 of set 1 |kupang
# Processing Record 553 of set 1 |medford
# Processing Record 554 of set 1 |lolua
# Processing Record 555 of set 1 |bangui
# Processing Record 556 of set 1 |marawi
# Processing Record 557 of set 1 |westport
# Processing Record 558 of set 1 |mandalgovi
# Processing Record 559 of set 1 |kawalu
# Processing Record 560 of set 1 |gizo
# Processing Record 561 of set 1 |puerto vallarta
# Processing Record 562 of set 1 |rosetta
# Processing Record 563 of set 1 |camacupa
# Processing Record 564 of set 1 |kavaratti
# Processing Record 565 of set 1 |abengourou
# Processing Record 566 of set 1 |norrtalje
# Processing Record 567 of set 1 |kodino
# Processing Record 568 of set 1 |iqaluit
# Processing Record 569 of set 1 |tandil
# Processing Record 570 of set 1 |kuvandyk
# Processing Record 571 of set 1 |kargala
# Processing Record 572 of set 1 |sayabec
# Processing Record 573 of set 1 |prince rupert
# Processing Record 574 of set 1 |morecambe
# Processing Record 575 of set 1 |rudbar
# Processing Record 576 of set 1 |khorixas
# Processing Record 577 of set 1 |temaraia
# Processing Record 578 of set 1 |taywarah
# Processing Record 579 of set 1 |keti bandar
# Processing Record 580 of set 1 |ciudad del maiz
# Processing Record 581 of set 1 |ous
# Processing Record 582 of set 1 |manokwari
# Processing Record 583 of set 1 |nago
# Processing Record 584 of set 1 |aykhal
# Processing Record 585 of set 1 |wanaka
# Processing Record 586 of set 1 |harper
# Processing Record 587 of set 1 |sibolga
# Processing Record 588 of set 1 |shimoda
# Processing Record 589 of set 1 |kieta
# Processing Record 590 of set 1 |tura
# Processing Record 591 of set 1 |manitouwadge
# Processing Record 592 of set 1 |rutul
# Processing Record 593 of set 1 |yatou
# -----------------------------
# Ending of Data Retrieval
# -----------------------------

# %%
lat=[]
lng=[]
max_temp=[]
humidity=[]
cloudiness=[]
windspeed=[]
Country=[]
Date=[]
cityname=[]
cityid=[]
counter= 0

for city in cities:
    response=requests.get(query_url + city+"&units=" + units).json()
    counter = counter + 1
    try: 
  
           #humidity= response["main"]["humidity"]
           lat.append(response["coord"]["lat"])
           lng.append(response["coord"]["lon"])
           humidity.append(response["main"]["humidity"])
           max_temp.append(response["main"]["temp_max"]) 
           cloudiness.append(response["clouds"]["all"]) 
           windspeed.append(response["wind"]["speed"])
           Country.append(response["sys"]["country"])
           Date.append(response["dt"])
           cityname.append(response["name"])
           cityid.append(counter)
            
           #cityid.append(response["id"]) 
        
    except:
            #print(f'latitude not found. Skipping...:{city}')
            pass
#print(f'latitude :{lat}') 
#len(lat)
#print(f'humidity:{humidity}')
#len(humidity)
#print(f'logitude:{lng}')
#print(f'Maximum temperature:{max_temp}')
#print(f'Clodiness:{cloudiness}')
#print(f'wind speed:{ windspeed}')
# print(f'Country:{Country}')
# print(f'Date:{Date}')
#print(f'cityid:{cityid}')
#print(f'cityname:{cityname}')
#print(f'cityid:{cityid}')

# %%
Raw_dict={"Cityid":cityid,"City":cityname,"Cloudiness":cloudiness,"Country":Country,"Date":Date,"Humidity":humidity,
                      "latitude":lat,"Longitude":lng,"Maxtemp":max_temp,"Windspeed":windspeed}
raw_data=pd.DataFrame(Raw_dict)
raw_data
# Out:
#      Cityid          City  Cloudiness Country        Date  Humidity  latitude  \
# 0         1  Saint-Pierre          75      RE  1595103628        88    -21.34
# 1         2      Itaituba          52      BR  1595103398        30     -4.28
# 2         3     Jamestown           1      US  1595103523        58     42.10
# 3         4         Bluff           0      NZ  1595103628        82    -46.60
# 4         5  Punta Arenas          40      CL  1595103368        80    -53.15
# ..      ...           ...         ...     ...         ...       ...       ...
# 539     589         Kieta         100      PG  1595103671        81     -6.22
# 540     590          Tura         100      IN  1595103671        98     25.52
# 541     591  Manitouwadge          90      CA  1595103671       100     49.12
# 542     592         Rutul           0      RU  1595103604        51     41.54
# 543     593         Yatou         100      CN  1595103671        97     37.15
#
#      Longitude  Maxtemp  Windspeed
# 0        55.48    19.00       9.30
# 1       -55.98    35.39       1.77
# 2       -79.24    30.56       4.60
# 3       168.33     2.55       3.89
# 4       -70.92     2.00       8.20
# ..         ...      ...        ...
# 539     155.63    25.61       0.97
# 540      90.22    24.06       2.85
# 541     -85.84    18.00       2.10
# 542      47.42    28.00       6.20
# 543     122.38    22.07       7.14
#
# [544 rows x 10 columns]

# %%
# Identify incomplete rows
raw_data.count()
# Out:
# Cityid        544
# City          544
# Cloudiness    544
# Country       544
# Date          544
# Humidity      544
# latitude      544
# Longitude     544
# Maxtemp       544
# Windspeed     544
# dtype: int64

# %%
# Collecting a summary of all numeric data
raw_data_df=raw_data.describe()
raw_data_df
# Out:
#            Cityid  Cloudiness          Date    Humidity    latitude  \
# count  544.000000  544.000000  5.440000e+02  544.000000  544.000000
# mean   297.832721   45.349265  1.595104e+09   69.665441   17.902206
# std    171.190909   39.084638  8.150952e+01   21.737133   33.848896
# min      1.000000    0.000000  1.595103e+09    3.000000  -54.800000
# 25%    151.750000    3.000000  1.595104e+09   58.000000   -9.082500
# 50%    298.500000   40.000000  1.595104e+09   76.000000   20.875000
# 75%    446.250000   89.000000  1.595104e+09   87.000000   46.257500
# max    593.000000  100.000000  1.595104e+09  100.000000   78.220000
#
#         Longitude     Maxtemp   Windspeed
# count  544.000000  544.000000  544.000000
# mean    19.832077   21.052408    3.591875
# std     90.209819    8.379826    2.318994
# min   -179.170000   -1.110000    0.150000
# 25%    -60.280000   14.470000    1.960000
# 50%     24.545000   22.025000    3.100000
# 75%     99.142500   27.515000    5.100000
# max    179.320000   39.840000   15.130000

# %%
raw_data.reset_index(drop=True,inplace=True)
raw_data
# Out:
#      Cityid          City  Cloudiness Country        Date  Humidity  latitude  \
# 0         1  Saint-Pierre          75      RE  1595103628        88    -21.34
# 1         2      Itaituba          52      BR  1595103398        30     -4.28
# 2         3     Jamestown           1      US  1595103523        58     42.10
# 3         4         Bluff           0      NZ  1595103628        82    -46.60
# 4         5  Punta Arenas          40      CL  1595103368        80    -53.15
# ..      ...           ...         ...     ...         ...       ...       ...
# 539     589         Kieta         100      PG  1595103671        81     -6.22
# 540     590          Tura         100      IN  1595103671        98     25.52
# 541     591  Manitouwadge          90      CA  1595103671       100     49.12
# 542     592         Rutul           0      RU  1595103604        51     41.54
# 543     593         Yatou         100      CN  1595103671        97     37.15
#
#      Longitude  Maxtemp  Windspeed
# 0        55.48    19.00       9.30
# 1       -55.98    35.39       1.77
# 2       -79.24    30.56       4.60
# 3       168.33     2.55       3.89
# 4       -70.92     2.00       8.20
# ..         ...      ...        ...
# 539     155.63    25.61       0.97
# 540      90.22    24.06       2.85
# 541     -85.84    18.00       2.10
# 542      47.42    28.00       6.20
# 543     122.38    22.07       7.14
#
# [544 rows x 10 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Export the city data into a csv
raw_data.to_csv("../OutputData/Rawcitydata.csv", index=False)

# %% [markdown]
# # Inspect the data and remove the cities where the humidity > 100%.
#
# #Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_over_hundper=raw_data[(raw_data["Humidity"]> 100)].index
                                   
humidity_over_hundper
# Out:
# Int64Index([], dtype='int64')

# %%
## Make a new DataFrame equal to the city data to drop all humidity outliers by index.


city_data=raw_data.drop(raw_data[raw_data['Humidity']>100].index)
city_data
# Out:
#      Cityid          City  Cloudiness Country        Date  Humidity  latitude  \
# 0         1  Saint-Pierre          75      RE  1595103628        88    -21.34
# 1         2      Itaituba          52      BR  1595103398        30     -4.28
# 2         3     Jamestown           1      US  1595103523        58     42.10
# 3         4         Bluff           0      NZ  1595103628        82    -46.60
# 4         5  Punta Arenas          40      CL  1595103368        80    -53.15
# ..      ...           ...         ...     ...         ...       ...       ...
# 539     589         Kieta         100      PG  1595103671        81     -6.22
# 540     590          Tura         100      IN  1595103671        98     25.52
# 541     591  Manitouwadge          90      CA  1595103671       100     49.12
# 542     592         Rutul           0      RU  1595103604        51     41.54
# 543     593         Yatou         100      CN  1595103671        97     37.15
#
#      Longitude  Maxtemp  Windspeed
# 0        55.48    19.00       9.30
# 1       -55.98    35.39       1.77
# 2       -79.24    30.56       4.60
# 3       168.33     2.55       3.89
# 4       -70.92     2.00       8.20
# ..         ...      ...        ...
# 539     155.63    25.61       0.97
# 540      90.22    24.06       2.85
# 541     -85.84    18.00       2.10
# 542      47.42    28.00       6.20
# 543     122.38    22.07       7.14
#
# [544 rows x 10 columns]

# %%
# # need to check:potential outlier >lower bound and lessthan upperbound which meansabove 14 and below 130
# city_data=raw_data.loc[(raw_data["Humidity"] > lower_bound) &(raw_data["Humidity"]< upper_bound)]
# city_data

# %%
# # Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# city_data_df=raw_data.loc[(raw_data["Humidity"] > lower_bound) &(raw_data["Humidity"]< upper_bound)]
# city_data_df

# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data= city_data.reset_index(drop=True,inplace=False)
clean_city_data
# Out:
#      Cityid          City  Cloudiness Country        Date  Humidity  latitude  \
# 0         1  Saint-Pierre          75      RE  1595103628        88    -21.34
# 1         2      Itaituba          52      BR  1595103398        30     -4.28
# 2         3     Jamestown           1      US  1595103523        58     42.10
# 3         4         Bluff           0      NZ  1595103628        82    -46.60
# 4         5  Punta Arenas          40      CL  1595103368        80    -53.15
# ..      ...           ...         ...     ...         ...       ...       ...
# 539     589         Kieta         100      PG  1595103671        81     -6.22
# 540     590          Tura         100      IN  1595103671        98     25.52
# 541     591  Manitouwadge          90      CA  1595103671       100     49.12
# 542     592         Rutul           0      RU  1595103604        51     41.54
# 543     593         Yatou         100      CN  1595103671        97     37.15
#
#      Longitude  Maxtemp  Windspeed
# 0        55.48    19.00       9.30
# 1       -55.98    35.39       1.77
# 2       -79.24    30.56       4.60
# 3       168.33     2.55       3.89
# 4       -70.92     2.00       8.20
# ..         ...      ...        ...
# 539     155.63    25.61       0.97
# 540      90.22    24.06       2.85
# 541     -85.84    18.00       2.10
# 542      47.42    28.00       6.20
# 543     122.38    22.07       7.14
#
# [544 rows x 10 columns]

# %%
# Extract relevant fields from the data frame
# Reorganizing the columns using double brackets

City_Data = clean_city_data[["City","latitude","Longitude","Maxtemp","Humidity","Cloudiness","Windspeed","Country","Date"]]
City_Data 
# Export the City_Data into a csv
# Out:
#              City  latitude  Longitude  Maxtemp  Humidity  Cloudiness  \
# 0    Saint-Pierre    -21.34      55.48    19.00        88          75
# 1        Itaituba     -4.28     -55.98    35.39        30          52
# 2       Jamestown     42.10     -79.24    30.56        58           1
# 3           Bluff    -46.60     168.33     2.55        82           0
# 4    Punta Arenas    -53.15     -70.92     2.00        80          40
# ..            ...       ...        ...      ...       ...         ...
# 539         Kieta     -6.22     155.63    25.61        81         100
# 540          Tura     25.52      90.22    24.06        98         100
# 541  Manitouwadge     49.12     -85.84    18.00       100          90
# 542         Rutul     41.54      47.42    28.00        51           0
# 543         Yatou     37.15     122.38    22.07        97         100
#
#      Windspeed Country        Date
# 0         9.30      RE  1595103628
# 1         1.77      BR  1595103398
# 2         4.60      US  1595103523
# 3         3.89      NZ  1595103628
# 4         8.20      CL  1595103368
# ..         ...     ...         ...
# 539       0.97      PG  1595103671
# 540       2.85      IN  1595103671
# 541       2.10      CA  1595103671
# 542       6.20      RU  1595103604
# 543       7.14      CN  1595103671
#
# [544 rows x 9 columns]

# %%
# Export the City_Data into a csv

City_Data.to_csv("Outputdata/CityData.csv", index=False,header=True)
#City_Data.to_csv("../OutputData/CityData.csv", index=False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
City_Data
# Out:
#              City  latitude  Longitude  Maxtemp  Humidity  Cloudiness  \
# 0    Saint-Pierre    -21.34      55.48    19.00        88          75
# 1        Itaituba     -4.28     -55.98    35.39        30          52
# 2       Jamestown     42.10     -79.24    30.56        58           1
# 3           Bluff    -46.60     168.33     2.55        82           0
# 4    Punta Arenas    -53.15     -70.92     2.00        80          40
# ..            ...       ...        ...      ...       ...         ...
# 539         Kieta     -6.22     155.63    25.61        81         100
# 540          Tura     25.52      90.22    24.06        98         100
# 541  Manitouwadge     49.12     -85.84    18.00       100          90
# 542         Rutul     41.54      47.42    28.00        51           0
# 543         Yatou     37.15     122.38    22.07        97         100
#
#      Windspeed Country        Date
# 0         9.30      RE  1595103628
# 1         1.77      BR  1595103398
# 2         4.60      US  1595103523
# 3         3.89      NZ  1595103628
# 4         8.20      CL  1595103368
# ..         ...     ...         ...
# 539       0.97      PG  1595103671
# 540       2.85      IN  1595103671
# 541       2.10      CA  1595103671
# 542       6.20      RU  1595103604
# 543       7.14      CN  1595103671
#
# [544 rows x 9 columns]

# %%
import datetime
today = datetime.datetime.now()
print(today.strftime("%x"))
# Out:
# 07/18/20

# %%
# Plot out Latitude versus maxtemperature 

x_values = City_Data['latitude']
y_values = City_Data['Maxtemp']

plt.scatter(x_values,y_values)

plt.title("Latitude versus maxtemperature"+" "+"("+today.strftime("%x")+")")
plt.xlabel('Latitude')
plt.ylabel('maximum Temperature')
plt.grid()
plt.savefig("../Images/lat_temp.png")
plt.show()

# %% [markdown]
# ### Analysis: Latitude vs maxtemperature(7/17/2020)
#
# This sctterplot shows while latitude increasing temperature is decreasing,so gives a negative correlation.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plot out Latitude versus Humidity 
x_values = City_Data['latitude']
y_values = City_Data['Humidity']
plt.scatter(x_values,y_values)
plt.title("latitude vs Humidity "+" "+"("+today.strftime("%x")+")")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid()
plt.savefig("../Images/lat_humidity.png")
plt.show()

# %% [markdown]
# ### Analysis:Latitude vs Humidity(7/17/2020)
#
#
# There is no correlation between the latitude and the Humidity .

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plot out Latitude versus Cloudiness
x_values = City_Data['latitude']
y_values = City_Data['Cloudiness']
plt.scatter(x_values,y_values)
plt.title("Latitude versus Cloudiness "+" "+"("+today.strftime("%x")+")")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid()
plt.savefig("../Images/lat_cloudiness.png")
plt.show()

# %% [markdown]
# ### Analysis:Latitude vs Cloudiness(7/17/2020)
# There is no correlation between the latitude and the cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plot out Latitude versus Windspeed 
x_values = City_Data['latitude']
y_values = City_Data['Windspeed']
plt.scatter(x_values,y_values)
plt.title('Latitude versus Windspeed(7/17/2020)')
plt.xlabel('Latitude')
plt.ylabel('Windspeed')
plt.grid()
plt.savefig("../Images/lat_windspeed.png")
plt.show()

# %% [markdown]
# Analysis:Latitude vs Windspeed
# There is no correlation between Latitude vs windspeed

# %% [markdown]
# ## Linear Regression

# %%
# Add the linear regression equation and line to plot for latitude vs windspeed
x_values =  City_Data['latitude']
y_values = City_Data['Windspeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title('latitude vs windspeed')
plt.xlabel('Latitude')
plt.ylabel('wind speed')
plt.show()

# %%
# Add the linear regression equation and line to plot for Latitude versus maxtemperature 
x_values =  City_Data['latitude']
y_values = City_Data['Maxtemp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,30),fontsize=15,color="red")
plt.title('Latitude versus maxtemperature ')
plt.xlabel('Latitude')
plt.ylabel('Maxtemperature')
plt.show()

# %%
#Northern Hemisphere (greater than or equal to 0 degrees latitude)
# Create Northern DataFrame
North_hemisphere=City_Data.loc[City_Data['latitude']>=0]
North_hemisphere
# Out:
#              City  latitude  Longitude  Maxtemp  Humidity  Cloudiness  \
# 2       Jamestown     42.10     -79.24    30.56        58           1
# 8           Yanam     16.73      82.22    26.81        85          86
# 12    Clyde River     70.47     -68.59     7.00        81          75
# 14      Khelyulya     61.73      30.68    17.03        66          62
# 15    Fort Nelson     58.81    -122.70    23.00        46          75
# ..            ...       ...        ...      ...       ...         ...
# 538       Shimoda     34.67     138.95    19.44        96         100
# 540          Tura     25.52      90.22    24.06        98         100
# 541  Manitouwadge     49.12     -85.84    18.00       100          90
# 542         Rutul     41.54      47.42    28.00        51           0
# 543         Yatou     37.15     122.38    22.07        97         100
#
#      Windspeed Country        Date
# 2         4.60      US  1595103523
# 8         1.52      IN  1595103628
# 12        7.70      CA  1595103628
# 14        1.24      RU  1595103628
# 15        1.50      CA  1595103628
# ..         ...     ...         ...
# 538       5.14      JP  1595103670
# 540       2.85      IN  1595103671
# 541       2.10      CA  1595103671
# 542       6.20      RU  1595103604
# 543       7.14      CN  1595103671
#
# [359 rows x 9 columns]

# %%
# Create Southern Hemisphere DataFrame
# Southern Hemisphere (less than 0 degrees latitude):
south_hemisphere=City_Data.loc[City_Data['latitude']<0]
south_hemisphere
# Out:
#              City  latitude  Longitude  Maxtemp  Humidity  Cloudiness  \
# 0    Saint-Pierre    -21.34      55.48    19.00        88          75
# 1        Itaituba     -4.28     -55.98    35.39        30          52
# 3           Bluff    -46.60     168.33     2.55        82           0
# 4    Punta Arenas    -53.15     -70.92     2.00        80          40
# 5    Kruisfontein    -34.00      24.73    12.35        73           0
# ..            ...       ...        ...      ...       ...         ...
# 521        Tandil    -37.32     -59.13    15.56        71         100
# 527      Khorixas    -20.37      14.97    15.46        31           0
# 532     Manokwari     -0.87     134.08    26.06        76          10
# 535        Wanaka    -44.70     169.15    -1.11        88           0
# 539         Kieta     -6.22     155.63    25.61        81         100
#
#      Windspeed Country        Date
# 0         9.30      RE  1595103628
# 1         1.77      BR  1595103398
# 3         3.89      NZ  1595103628
# 4         8.20      CL  1595103368
# 5         3.62      ZA  1595103628
# ..         ...     ...         ...
# 521       0.45      AR  1595103520
# 527       5.17      NA  1595103670
# 532       1.45      ID  1595103670
# 535       1.34      NZ  1595103670
# 539       0.97      PG  1595103671
#
# [185 rows x 9 columns]

# %%
# North_hemisphere=City_Data.loc[City_Data['latitude']>=0]
# North_hemisp# Create Northern and Southern Hemisphere DataFrameshere

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Northern Hemisphere:Add the linear regression equation and line to plot for Max Temp vs. Latitude 

x_values = North_hemisphere['latitude']
y_values =North_hemisphere  ['Maxtemp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.title('Northern Hemisphere - Max Temp vs. Latitude')
plt.xlabel('latitude')
plt.ylabel('Maxtemperature')

print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.45387504365289894

# %% [markdown]
# # Analysis:
# There is a negative correlation between the longitute and the maximum temperature, The best fit line discribes the data is negatively correlated.when the lagitude increases the temperture is decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern Hemisphere: Add the linear regression equation and line to plot for Max Temp vs. Latitude 

x_values = south_hemisphere['latitude']
y_values = south_hemisphere['Maxtemp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-45,20),fontsize=15,color="red")
plt.title('Southern Hemisphere - Max Temp vs. Latitude')
plt.xlabel('latitude')
plt.ylabel('Maxtemperature')

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.6166767747777782

# %% [markdown]
# # Analysis:
# There is a strong correlation between the longitute and the maximum temperature, The best fit line discribes the data is strongly correlated.when the lagitude increases the temperture is decreases in the sothern hemishere..

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere: Add the linear regression equation and line to plot for Humidity vs. Latitude 

x_values = North_hemisphere['latitude']
y_values =North_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,60),fontsize=15,color="red")
plt.title('Northern Hemisphere - Humidity vs. Latitude')
plt.xlabel('latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 4.293644182248076e-05

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere: Add the linear regression equation and line to plot for Humidity vs. Latitude 

x_values = south_hemisphere['latitude']
y_values =south_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-45,60),fontsize=15,color="red")
plt.title('Southern Hemisphere - Humidity vs. Latitude')
plt.xlabel('latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.06635638869851948

# %% [markdown]
# # Analysis:
# Southern Hemisphere - Humidity vs. Latitude :There is no significant realtion between the latitude and the humidity.There is no dependency between the variables longitude and humidity.
# Cloudiness (%) vs. Latitude :There is no significant realtion between the latitude and the clodiness.There is no dependency between the variables longitude and cloudiness.
# Wind Speed (mph) vs. Latitude:There is no significant correaltion between the latitude and the windspeed.There is no dependency between the variables longitude and windspeed.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere: Add the linear regression equation and line to plot for Cloudiness(%) vs. Latitude 

x_values = North_hemisphere['latitude']
y_values =North_hemisphere  ['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,80),fontsize=15,color="red")
plt.title('Northern Hemisphere - Cloudiness(%) vs. Latitude')
plt.xlabel('latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0036098829957136765

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere: Add the linear regression equation and line to plot for Cloudiness(%) vs. Latitude 

x_values = south_hemisphere['latitude']
y_values =south_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-45,60),fontsize=15,color="red")
plt.title('Southern Hemisphere - Cloudiness(%) vs. Latitude')
plt.xlabel('latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0007923237968299104

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Northern Hemisphere: Add the linear regression equation and line to plot for Cloudiness(%) vs. Latitude 

x_values = North_hemisphere['latitude']
y_values =North_hemisphere  ['Windspeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,10),fontsize=15,color="red")
plt.title('Northern Hemisphere - Windspeed vs. Latitude')
plt.xlabel('latitude')
plt.ylabel('Windspeed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.008752201719480343

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Southern Hemisphere: Add the linear regression equation and line to plot for Cloudiness(%) vs. Latitude 

x_values = south_hemisphere['latitude']
y_values =south_hemisphere['Windspeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-45,6),fontsize=15,color="red")
plt.title('Southern Hemisphere - Windspeed vs. Latitude')
plt.xlabel('latitude')
plt.ylabel('Windspeed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.019631779998831027

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def weather_regress(x_values,y_values,title,ylabel):
   
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(-45,6),fontsize=15,color="red")
    plt.title(title)
    plt.xlabel('latitude')
    plt.ylabel(ylabel)
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
x_values = south_hemisphere['latitude']
y_values =south_hemisphere['Windspeed']
weather_regress(x_values,y_values,'Southern Hemisphere - Windspeed vs. Latitude','Windspeed')
# Out:
# The r-squared is: 0.019631779998831027

# %%
x_values = south_hemisphere['latitude']
y_values =south_hemisphere['Cloudiness']
weather_regress(x_values,y_values,'Southern Hemisphere - Windspeed vs. Latitude','Windspeed')
# Out:
# The r-squared is: 0.0007923237968299104

# %% [markdown]
# # Obsevable Trends:
# There is a negative correlation between the longitute and the maximum temperature, The best fit line discribes the data is negatively correlated.when the lagitude increases the temperture is decreases.
#
# There is no significant relation between the latitude and the humidity,Cloudiness (%) vs. Latitude,Wind Speed (mph) vs. Latitude.There is no dependency between the variables .
# Based on linear regression equation(latitude vs maxtemerature)we can predict the future temperature.
